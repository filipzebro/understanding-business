# %% [markdown]
# # MEAL: purchase driver analysis
#
# Business question: which booking, route, passenger and sales-context factors are most associated with buying **MEAL**?
#
# Core KPI:
#
# | Metric | Value |
# |---|---:|
# | Offers | 390,162 |
# | Purchases | 4,395 |
# | Conversion rate | 1.13% |
# | Revenue | 17,226 |
# | Avg sold price | 3.92 |
#
# Interpretation rule: this is directional driver analysis, not causal proof. The production recommendation should be validated with an A/B test.

# %% [markdown]
# ## Strongest segments by conversion lift
#
# These are the segments where conversion is highest versus the product baseline, after filtering out low-volume groups.
#
# | driver           | segment_value    |   offers |   conversion_rate |   cr_lift_vs_product |   revenue |
# |:-----------------|:-----------------|---------:|------------------:|---------------------:|----------:|
# | route_direction  | AREA_B_TO_AREA_D |      504 |            0.0516 |               4.5796 |  127.7439 |
# | MARKET           | OLD HORIZON      |      756 |            0.0463 |               4.1099 |  128.2900 |
# | FLIGHT_TYPE      | Multi-City       |     2314 |            0.0419 |               3.7213 |  461.7207 |
# | route_direction  | AREA_D_TO_AREA_B |      546 |            0.0385 |               3.4144 |   76.4194 |
# | MARKET           | GREAT HORIZON    |      687 |            0.0364 |               3.2305 |   74.7760 |
# | MARKET           | CENTRAL VERTEX   |     2670 |            0.0363 |               3.2251 |  183.1492 |
# | MARKET           | UPPER AURORA     |      613 |            0.0326 |               2.8964 |   33.5723 |
# | first_rbd        | Y                |     1432 |            0.0307 |               2.7277 |  215.7386 |
# | first_rbd        | I                |     1793 |            0.0240 |               2.1290 |  180.8694 |
# | MARKET           | EAST HORIZON     |     1034 |            0.0232 |               2.0605 |   81.7064 |
# | is_hub_caj_route | 0                |    92392 |            0.0215 |               1.9111 | 7208.3434 |
# | MARKET           | WEST MERIDIAN    |     1099 |            0.0209 |               1.8579 |   80.3307 |

# %% [markdown]
# ## Biggest revenue segments
#
# These are often more useful for the business pitch than pure CR, because they combine volume, price and conversion.
#
# | driver              | segment_value   |   offers |   purchases |   conversion_rate |    revenue |
# |:--------------------|:----------------|---------:|------------:|------------------:|-----------:|
# | first_booking_class | Y               |   380458 |        4220 |            0.0111 | 16481.9995 |
# | has_loyalty         | 0               |   355485 |        4087 |            0.0115 | 16083.4856 |
# | has_child_or_infant | 0               |   365637 |        3992 |            0.0109 | 14443.1317 |
# | LOGIN_STATUS        | Logged-Out      |   275694 |        3141 |            0.0114 | 12366.4854 |
# | FLIGHT_TYPE         | Round-Trip      |   275538 |        2390 |            0.0087 | 11421.3459 |
# | origin_area         | AREA_C          |   276674 |        2853 |            0.0103 | 11138.0173 |
# | is_hub_caj_route    | 1               |   297770 |        2406 |            0.0081 | 10017.8989 |
# | BROWSER_TYPE        | google          |   179672 |        2173 |            0.0121 |  8571.6193 |
# | destination_area    | AREA_C          |   228973 |        2441 |            0.0107 |  8425.0302 |
# | pax_bucket          | 1               |   265335 |        2937 |            0.0111 |  8417.0647 |
# | destination_area    | AREA_B          |   151704 |        1815 |            0.0120 |  8107.6149 |
# | fare_bucket         | very_high       |    75882 |         959 |            0.0126 |  7573.7792 |

# %% [markdown]
# ## Driver summary
#
# Each row shows the best segment by conversion lift and the largest segment by revenue for a candidate driver.
#
# | driver                  | best_cr_segment   |   best_cr |   best_cr_lift | highest_revenue_segment   |   highest_segment_revenue |
# |:------------------------|:------------------|----------:|---------------:|:--------------------------|--------------------------:|
# | route_direction         | AREA_B_TO_AREA_D  |    0.0516 |         4.5796 | AREA_C_TO_AREA_B          |                 5984.1652 |
# | MARKET                  | OLD HORIZON       |    0.0463 |         4.1099 | UPPER APEX                |                 6603.2913 |
# | FLIGHT_TYPE             | Multi-City        |    0.0419 |         3.7213 | Round-Trip                |                11421.3459 |
# | first_rbd               | Y                 |    0.0307 |         2.7277 | O                         |                 2758.2212 |
# | is_hub_caj_route        | 0                 |    0.0215 |         1.9111 | 1                         |                10017.8989 |
# | first_booking_class     | C                 |    0.0179 |         1.5915 | Y                         |                16481.9995 |
# | stay_bucket             | unknown_or_oneway |    0.0170 |         1.5066 | unknown_or_oneway         |                 6331.6047 |
# | has_child_or_infant     | 1                 |    0.0164 |         1.4588 | 0                         |                14443.1317 |
# | display_position_bucket | 1                 |    0.0160 |         1.4188 | 1                         |                 6958.2252 |
# | origin_area             | AREA_D            |    0.0159 |         1.4089 | AREA_C                    |                11138.0173 |
# | FIRST_TOUCH_CHANNEL     | MetaSearches      |    0.0150 |         1.3357 | Direct                    |                 7240.3592 |
# | destination_area        | AREA_D            |    0.0147 |         1.3010 | AREA_C                    |                 8425.0302 |
# | LAST_TOUCH_CHANNEL      | MetaSearches      |    0.0142 |         1.2601 | Paid Search               |                 6197.8274 |
# | dtd_bucket              | 0_3               |    0.0137 |         1.2129 | 31_60                     |                 3274.7574 |
# | fare_bucket             | mid               |    0.0130 |         1.1535 | very_high                 |                 7573.7792 |
# | pax_bucket              | 3                 |    0.0127 |         1.1314 | 1                         |                 8417.0647 |
# | BROWSER_TYPE            | google            |    0.0121 |         1.0737 | google                    |                 8571.6193 |
# | emd_price_bucket        | very_low          |    0.0118 |         1.0518 | low                       |                 6170.8787 |
# | has_loyalty             | 0                 |    0.0115 |         1.0206 | 0                         |                16083.4856 |
# | LOGIN_STATUS            | Logged-Out        |    0.0114 |         1.0114 | Logged-Out                |                12366.4854 |

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
base = Path("outputs/problem1/product_driver_analysis")
if not base.exists():
    base = Path("../product_driver_analysis")
driver_df = pd.read_csv(base / "meal_driver_segments.csv")
driver_score = pd.read_csv(base / "meal_driver_score.csv")

driver_df.head()

# %%
plot_df = driver_score.sort_values("best_cr_lift", ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(data=plot_df, y="driver", x="best_cr_lift", color="#2F6F9F")
plt.axvline(1, color="black", linewidth=1)
plt.title("Top drivers by best-segment CR lift")
plt.xlabel("Lift vs product baseline")
plt.ylabel("")
plt.tight_layout()

# %%
plot_df = driver_df.sort_values("revenue", ascending=False).head(15)
plt.figure(figsize=(10, 6))
sns.barplot(data=plot_df, y="segment_value", x="revenue", hue="driver", dodge=False)
plt.title("Highest-revenue segments")
plt.xlabel("Revenue")
plt.ylabel("")
plt.legend(loc="lower right")
plt.tight_layout()

# %%
plot_df = driver_df[driver_df["driver"].isin(["fare_bucket", "dtd_bucket", "stay_bucket", "FLIGHT_TYPE", "display_position_bucket"])].copy()
plot_df = plot_df.sort_values(["driver", "segment_value"])
g = sns.catplot(
    data=plot_df,
    kind="bar",
    x="segment_value",
    y="conversion_rate",
    col="driver",
    col_wrap=2,
    sharex=False,
    sharey=False,
    color="#2F6F9F",
    height=3.2,
    aspect=1.5,
)
g.set_xticklabels(rotation=35, ha="right")
g.set_axis_labels("", "Conversion rate")
g.fig.suptitle("Conversion rate by selected business buckets", y=1.03)
plt.tight_layout()

# %%
# Use this table to pick slide examples: high lift, enough volume, and meaningful revenue.
driver_df.query("offers >= 1000").sort_values(
    ["cr_lift_vs_product", "revenue"],
    ascending=False,
).head(25)
