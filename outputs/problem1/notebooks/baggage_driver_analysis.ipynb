# %% [markdown]
# # BAGGAGE: purchase driver analysis
#
# Business question: which booking, route, passenger and sales-context factors are most associated with buying **BAGGAGE**?
#
# Core KPI:
#
# | Metric | Value |
# |---|---:|
# | Offers | 500,999 |
# | Purchases | 26,292 |
# | Conversion rate | 5.25% |
# | Revenue | 392,588 |
# | Avg sold price | 14.93 |
#
# Interpretation rule: this is directional driver analysis, not causal proof. The production recommendation should be validated with an A/B test.

# %% [markdown]
# ## Strongest segments by conversion lift
#
# These are the segments where conversion is highest versus the product baseline, after filtering out low-volume groups.
#
# | driver              | segment_value   |   offers |   conversion_rate |   cr_lift_vs_product |     revenue |
# |:--------------------|:----------------|---------:|------------------:|---------------------:|------------:|
# | pax_bucket          | 4_plus          |    25354 |            0.1866 |               3.5557 | 102949.5120 |
# | has_child_or_infant | 1               |    31312 |            0.1825 |               3.4779 |  97580.2019 |
# | pax_bucket          | 3               |    26653 |            0.1432 |               2.7282 |  58310.9052 |
# | MARKET              | OLD MERIDIAN    |      424 |            0.1297 |               2.4718 |    651.0387 |
# | FLIGHT_TYPE         | Multi-City      |     4963 |            0.1233 |               2.3497 |  14297.6905 |
# | fare_bucket         | very_high       |    97972 |            0.1043 |               1.9874 | 226817.7798 |
# | MARKET              | EAST MERIDIAN   |      495 |            0.1010 |               1.9248 |    513.5908 |
# | MARKET              | EAST VERTEX     |      944 |            0.0922 |               1.7561 |   1108.6366 |
# | MARKET              | LOWER HORIZON   |      869 |            0.0921 |               1.7542 |   1074.2633 |
# | dtd_bucket          | 120_plus        |    52168 |            0.0911 |               1.7368 |  93137.0819 |
# | MARKET              | WEST AURORA     |     1415 |            0.0898 |               1.7103 |   1632.0076 |
# | MARKET              | EAST ZENITH     |     1715 |            0.0880 |               1.6777 |   3077.2747 |

# %% [markdown]
# ## Biggest revenue segments
#
# These are often more useful for the business pitch than pure CR, because they combine volume, price and conversion.
#
# | driver              | segment_value   |   offers |   purchases |   conversion_rate |     revenue |
# |:--------------------|:----------------|---------:|------------:|------------------:|------------:|
# | first_booking_class | Y               |   490027 |       26046 |            0.0532 | 388151.9820 |
# | has_loyalty         | 0               |   458263 |       24861 |            0.0543 | 370439.1494 |
# | has_child_or_infant | 0               |   469687 |       20577 |            0.0438 | 295007.8224 |
# | FLIGHT_TYPE         | Round-Trip      |   325093 |       16277 |            0.0501 | 280952.4097 |
# | LOGIN_STATUS        | Logged-Out      |   354319 |       18894 |            0.0533 | 279596.4466 |
# | origin_area         | AREA_C          |   341900 |       17487 |            0.0511 | 254452.4240 |
# | is_hub_caj_route    | 1               |   337115 |       15442 |            0.0458 | 226828.3456 |
# | fare_bucket         | very_high       |    97972 |       10218 |            0.1043 | 226817.7798 |
# | destination_area    | AREA_B          |   190281 |       12286 |            0.0646 | 205772.7008 |
# | BROWSER_TYPE        | google          |   232291 |       13476 |            0.0580 | 203663.3032 |
# | emd_price_bucket    | very_high       |    72960 |        6319 |            0.0866 | 197408.5239 |
# | MARKET              | UPPER APEX      |   247627 |       12452 |            0.0503 | 191189.9883 |

# %% [markdown]
# ## Driver summary
#
# Each row shows the best segment by conversion lift and the largest segment by revenue for a candidate driver.
#
# | driver                  | best_cr_segment   |   best_cr |   best_cr_lift | highest_revenue_segment   |   highest_segment_revenue |
# |:------------------------|:------------------|----------:|---------------:|:--------------------------|--------------------------:|
# | pax_bucket              | 4_plus            |    0.1866 |         3.5557 | 2                         |               123077.2607 |
# | has_child_or_infant     | 1                 |    0.1825 |         3.4779 | 0                         |               295007.8224 |
# | MARKET                  | OLD MERIDIAN      |    0.1297 |         2.4718 | UPPER APEX                |               191189.9883 |
# | FLIGHT_TYPE             | Multi-City        |    0.1233 |         2.3497 | Round-Trip                |               280952.4097 |
# | fare_bucket             | very_high         |    0.1043 |         1.9874 | very_high                 |               226817.7798 |
# | dtd_bucket              | 120_plus          |    0.0911 |         1.7368 | 120_plus                  |                93137.0819 |
# | emd_price_bucket        | very_high         |    0.0866 |         1.6504 | very_high                 |               197408.5239 |
# | route_direction         | AREA_D_TO_AREA_B  |    0.0859 |         1.6378 | AREA_C_TO_AREA_B          |               150494.0834 |
# | stay_bucket             | 15_30             |    0.0839 |         1.5995 | unknown_or_oneway         |               120165.0588 |
# | FIRST_TOUCH_CHANNEL     | Display           |    0.0783 |         1.4923 | Direct                    |               164663.9910 |
# | LAST_TOUCH_CHANNEL      | Organic Social    |    0.0741 |         1.4115 | Paid Search               |               142086.6255 |
# | destination_area        | AREA_D            |    0.0725 |         1.3809 | AREA_B                    |               205772.7008 |
# | first_rbd               | J                 |    0.0706 |         1.3459 | O                         |                90973.7750 |
# | is_hub_caj_route        | 0                 |    0.0662 |         1.2616 | 1                         |               226828.3456 |
# | BROWSER_TYPE            | opera             |    0.0629 |         1.1986 | google                    |               203663.3032 |
# | display_position_bucket | 2                 |    0.0598 |         1.1397 | 2                         |               154514.0404 |
# | origin_area             | AREA_D            |    0.0598 |         1.1388 | AREA_C                    |               254452.4240 |
# | has_loyalty             | 0                 |    0.0543 |         1.0338 | 0                         |               370439.1494 |
# | LOGIN_STATUS            | Logged-Out        |    0.0533 |         1.0161 | Logged-Out                |               279596.4466 |
# | first_booking_class     | Y                 |    0.0532 |         1.0128 | Y                         |               388151.9820 |

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
base = Path("outputs/problem1/product_driver_analysis")
if not base.exists():
    base = Path("../product_driver_analysis")
driver_df = pd.read_csv(base / "baggage_driver_segments.csv")
driver_score = pd.read_csv(base / "baggage_driver_score.csv")

driver_df.head()

# %%
plot_df = driver_score.sort_values("best_cr_lift", ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(data=plot_df, y="driver", x="best_cr_lift", color="#2F6F9F")
plt.axvline(1, color="black", linewidth=1)
plt.title("Top drivers by best-segment CR lift")
plt.xlabel("Lift vs product baseline")
plt.ylabel("")
plt.tight_layout()

# %%
plot_df = driver_df.sort_values("revenue", ascending=False).head(15)
plt.figure(figsize=(10, 6))
sns.barplot(data=plot_df, y="segment_value", x="revenue", hue="driver", dodge=False)
plt.title("Highest-revenue segments")
plt.xlabel("Revenue")
plt.ylabel("")
plt.legend(loc="lower right")
plt.tight_layout()

# %%
plot_df = driver_df[driver_df["driver"].isin(["fare_bucket", "dtd_bucket", "stay_bucket", "FLIGHT_TYPE", "display_position_bucket"])].copy()
plot_df = plot_df.sort_values(["driver", "segment_value"])
g = sns.catplot(
    data=plot_df,
    kind="bar",
    x="segment_value",
    y="conversion_rate",
    col="driver",
    col_wrap=2,
    sharex=False,
    sharey=False,
    color="#2F6F9F",
    height=3.2,
    aspect=1.5,
)
g.set_xticklabels(rotation=35, ha="right")
g.set_axis_labels("", "Conversion rate")
g.fig.suptitle("Conversion rate by selected business buckets", y=1.03)
plt.tight_layout()

# %%
# Use this table to pick slide examples: high lift, enough volume, and meaningful revenue.
driver_df.query("offers >= 1000").sort_values(
    ["cr_lift_vs_product", "revenue"],
    ascending=False,
).head(25)
