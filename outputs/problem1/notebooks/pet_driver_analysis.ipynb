# %% [markdown]
# # PET: purchase driver analysis
#
# Business question: which booking, route, passenger and sales-context factors are most associated with buying **PET**?
#
# Core KPI:
#
# | Metric | Value |
# |---|---:|
# | Offers | 373,662 |
# | Purchases | 4,351 |
# | Conversion rate | 1.16% |
# | Revenue | 94,555 |
# | Avg sold price | 21.73 |
#
# Interpretation rule: this is directional driver analysis, not causal proof. The production recommendation should be validated with an A/B test.

# %% [markdown]
# ## Strongest segments by conversion lift
#
# These are the segments where conversion is highest versus the product baseline, after filtering out low-volume groups.
#
# | driver              | segment_value    |   offers |   conversion_rate |   cr_lift_vs_product |   revenue |
# |:--------------------|:-----------------|---------:|------------------:|---------------------:|----------:|
# | MARKET              | WEST MERIDIAN    |     1049 |            0.0515 |               4.4209 | 1147.3913 |
# | MARKET              | GREAT MERIDIAN   |     4288 |            0.0410 |               3.5249 | 4023.1782 |
# | first_rbd           | Z                |     1422 |            0.0366 |               3.1405 | 1258.5548 |
# | FLIGHT_TYPE         | Multi-City       |     1597 |            0.0332 |               2.8501 | 1482.5673 |
# | route_direction     | AREA_B_TO_AREA_D |      587 |            0.0324 |               2.7797 |  377.4218 |
# | first_rbd           | F                |     1907 |            0.0309 |               2.6570 | 1485.8841 |
# | MARKET              | NORTH ZENITH     |     4153 |            0.0303 |               2.6055 | 2553.9495 |
# | first_rbd           | C                |      546 |            0.0293 |               2.5166 |  304.6091 |
# | MARKET              | GREAT APEX       |      571 |            0.0263 |               2.2560 |  289.1967 |
# | route_direction     | AREA_D_TO_AREA_B |      694 |            0.0259 |               2.2274 |  315.6134 |
# | first_booking_class | C                |     6424 |            0.0243 |               2.0855 | 3676.2038 |
# | MARKET              | LOWER APEX       |     1033 |            0.0232 |               1.9953 |  499.2453 |

# %% [markdown]
# ## Biggest revenue segments
#
# These are often more useful for the business pitch than pure CR, because they combine volume, price and conversion.
#
# | driver              | segment_value     |   offers |   purchases |   conversion_rate |    revenue |
# |:--------------------|:------------------|---------:|------------:|------------------:|-----------:|
# | first_booking_class | Y                 |   363820 |        4151 |            0.0114 | 89498.0498 |
# | has_loyalty         | 0                 |   340281 |        4003 |            0.0118 | 86717.6834 |
# | has_child_or_infant | 0                 |   350509 |        4015 |            0.0115 | 86627.9537 |
# | is_hub_caj_route    | 1                 |   304765 |        3075 |            0.0101 | 67301.9484 |
# | emd_price_bucket    | very_high         |   182818 |        2064 |            0.0113 | 62440.0363 |
# | origin_area         | AREA_C            |   264718 |        2926 |            0.0111 | 61385.0807 |
# | LOGIN_STATUS        | Logged-Out        |   262052 |        2783 |            0.0106 | 61186.8048 |
# | destination_area    | AREA_C            |   228348 |        2735 |            0.0120 | 58279.9511 |
# | FLIGHT_TYPE         | Round-Trip        |   255730 |        2106 |            0.0082 | 55559.7437 |
# | pax_bucket          | 1                 |   254994 |        2585 |            0.0101 | 53078.2498 |
# | FIRST_TOUCH_CHANNEL | Direct            |   186264 |        2423 |            0.0130 | 52407.1221 |
# | stay_bucket         | unknown_or_oneway |   127698 |        2342 |            0.0183 | 41708.0335 |

# %% [markdown]
# ## Driver summary
#
# Each row shows the best segment by conversion lift and the largest segment by revenue for a candidate driver.
#
# | driver                  | best_cr_segment   |   best_cr |   best_cr_lift | highest_revenue_segment   |   highest_segment_revenue |
# |:------------------------|:------------------|----------:|---------------:|:--------------------------|--------------------------:|
# | MARKET                  | WEST MERIDIAN     |    0.0515 |         4.4209 | UPPER APEX                |                40909.5867 |
# | first_rbd               | Z                 |    0.0366 |         3.1405 | O                         |                16254.6437 |
# | FLIGHT_TYPE             | Multi-City        |    0.0332 |         2.8501 | Round-Trip                |                55559.7437 |
# | route_direction         | AREA_B_TO_AREA_D  |    0.0324 |         2.7797 | AREA_C_TO_AREA_C          |                33835.7004 |
# | first_booking_class     | C                 |    0.0243 |         2.0855 | Y                         |                89498.0498 |
# | is_hub_caj_route        | 0                 |    0.0185 |         1.5905 | 1                         |                67301.9484 |
# | stay_bucket             | unknown_or_oneway |    0.0183 |         1.5750 | unknown_or_oneway         |                41708.0335 |
# | pax_bucket              | 2                 |    0.0165 |         1.4189 | 1                         |                53078.2498 |
# | origin_area             | AREA_D            |    0.0161 |         1.3800 | AREA_C                    |                61385.0807 |
# | BROWSER_TYPE            | apple             |    0.0154 |         1.3243 | google                    |                40553.8536 |
# | FIRST_TOUCH_CHANNEL     | Organic Search    |    0.0152 |         1.3012 | Direct                    |                52407.1221 |
# | LAST_TOUCH_CHANNEL      | Organic Search    |    0.0151 |         1.3001 | Direct                    |                36825.4267 |
# | has_child_or_infant     | 1                 |    0.0145 |         1.2463 | 0                         |                86627.9537 |
# | display_position_bucket | 5                 |    0.0142 |         1.2184 | 5                         |                26581.2981 |
# | LOGIN_STATUS            | Logged-In         |    0.0140 |         1.2065 | Logged-Out                |                61186.8048 |
# | fare_bucket             | low               |    0.0134 |         1.1476 | very_high                 |                22440.8565 |
# | emd_price_bucket        | high              |    0.0133 |         1.1405 | very_high                 |                62440.0363 |
# | dtd_bucket              | 15_30             |    0.0127 |         1.0931 | 15_30                     |                20075.9560 |
# | destination_area        | AREA_C            |    0.0120 |         1.0286 | AREA_C                    |                58279.9511 |
# | has_loyalty             | 0                 |    0.0118 |         1.0103 | 0                         |                86717.6834 |

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
base = Path("outputs/problem1/product_driver_analysis")
if not base.exists():
    base = Path("../product_driver_analysis")
driver_df = pd.read_csv(base / "pet_driver_segments.csv")
driver_score = pd.read_csv(base / "pet_driver_score.csv")

driver_df.head()

# %%
plot_df = driver_score.sort_values("best_cr_lift", ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(data=plot_df, y="driver", x="best_cr_lift", color="#2F6F9F")
plt.axvline(1, color="black", linewidth=1)
plt.title("Top drivers by best-segment CR lift")
plt.xlabel("Lift vs product baseline")
plt.ylabel("")
plt.tight_layout()

# %%
plot_df = driver_df.sort_values("revenue", ascending=False).head(15)
plt.figure(figsize=(10, 6))
sns.barplot(data=plot_df, y="segment_value", x="revenue", hue="driver", dodge=False)
plt.title("Highest-revenue segments")
plt.xlabel("Revenue")
plt.ylabel("")
plt.legend(loc="lower right")
plt.tight_layout()

# %%
plot_df = driver_df[driver_df["driver"].isin(["fare_bucket", "dtd_bucket", "stay_bucket", "FLIGHT_TYPE", "display_position_bucket"])].copy()
plot_df = plot_df.sort_values(["driver", "segment_value"])
g = sns.catplot(
    data=plot_df,
    kind="bar",
    x="segment_value",
    y="conversion_rate",
    col="driver",
    col_wrap=2,
    sharex=False,
    sharey=False,
    color="#2F6F9F",
    height=3.2,
    aspect=1.5,
)
g.set_xticklabels(rotation=35, ha="right")
g.set_axis_labels("", "Conversion rate")
g.fig.suptitle("Conversion rate by selected business buckets", y=1.03)
plt.tight_layout()

# %%
# Use this table to pick slide examples: high lift, enough volume, and meaningful revenue.
driver_df.query("offers >= 1000").sort_values(
    ["cr_lift_vs_product", "revenue"],
    ascending=False,
).head(25)
