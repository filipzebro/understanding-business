# %% [markdown]
# # SPECIAL EQUIPMENT: purchase driver analysis
#
# Business question: which booking, route, passenger and sales-context factors are most associated with buying **SPECIAL EQUIPMENT**?
#
# Core KPI:
#
# | Metric | Value |
# |---|---:|
# | Offers | 298,377 |
# | Purchases | 1,918 |
# | Conversion rate | 0.64% |
# | Revenue | 43,445 |
# | Avg sold price | 22.65 |
#
# Interpretation rule: this is directional driver analysis, not causal proof. The production recommendation should be validated with an A/B test.

# %% [markdown]
# ## Strongest segments by conversion lift
#
# These are the segments where conversion is highest versus the product baseline, after filtering out low-volume groups.
#
# | driver           | segment_value    |   offers |   conversion_rate |   cr_lift_vs_product |    revenue |
# |:-----------------|:-----------------|---------:|------------------:|---------------------:|-----------:|
# | FLIGHT_TYPE      | Multi-City       |      704 |            0.0384 |               5.9663 |   774.6542 |
# | MARKET           | NEW MERIDIAN     |     4871 |            0.0287 |               4.4712 |  3499.2821 |
# | route_direction  | AREA_B_TO_AREA_D |      630 |            0.0254 |               3.9509 |   255.0736 |
# | route_direction  | AREA_D_TO_AREA_B |      550 |            0.0236 |               3.6770 |   235.3144 |
# | MARKET           | EAST VERTEX      |      482 |            0.0228 |               3.5503 |   261.7851 |
# | first_rbd        | D                |      545 |            0.0220 |               3.4253 |   256.6245 |
# | MARKET           | GREAT APEX       |      441 |            0.0204 |               3.1748 |   146.1574 |
# | MARKET           | SOUTH ZENITH     |      540 |            0.0204 |               3.1690 |   257.0417 |
# | MARKET           | NEW APEX         |     1863 |            0.0199 |               3.0896 |   780.3789 |
# | MARKET           | LOWER ZENITH     |     4390 |            0.0182 |               2.8349 |  1976.9459 |
# | is_hub_caj_route | 0                |    43157 |            0.0169 |               2.6278 | 16194.0243 |
# | stay_bucket      | 6_8              |    35768 |            0.0156 |               2.4313 | 15064.2383 |

# %% [markdown]
# ## Biggest revenue segments
#
# These are often more useful for the business pitch than pure CR, because they combine volume, price and conversion.
#
# | driver              | segment_value   |   offers |   purchases |   conversion_rate |    revenue |
# |:--------------------|:----------------|---------:|------------:|------------------:|-----------:|
# | first_booking_class | Y               |   291513 |        1845 |            0.0063 | 41595.9696 |
# | has_child_or_infant | 0               |   279159 |        1732 |            0.0062 | 39185.8279 |
# | has_loyalty         | 0               |   271220 |        1747 |            0.0064 | 39145.2636 |
# | origin_area         | AREA_C          |   220212 |        1488 |            0.0068 | 35054.7296 |
# | FLIGHT_TYPE         | Round-Trip      |   205290 |        1324 |            0.0064 | 34870.9735 |
# | emd_price_bucket    | very_high       |   141364 |        1100 |            0.0078 | 33178.5799 |
# | LOGIN_STATUS        | Logged-Out      |   209560 |        1397 |            0.0067 | 31716.0750 |
# | is_hub_caj_route    | 1               |   255220 |        1189 |            0.0047 | 27250.6633 |
# | MARKET              | UPPER APEX      |   166685 |        1092 |            0.0066 | 25484.7571 |
# | BROWSER_TYPE        | google          |   134639 |         966 |            0.0072 | 22263.5013 |
# | destination_area    | AREA_B          |   113143 |         879 |            0.0078 | 21303.5799 |
# | FIRST_TOUCH_CHANNEL | Direct          |   148875 |         918 |            0.0062 | 20667.0409 |

# %% [markdown]
# ## Driver summary
#
# Each row shows the best segment by conversion lift and the largest segment by revenue for a candidate driver.
#
# | driver                  | best_cr_segment   |   best_cr |   best_cr_lift | highest_revenue_segment   |   highest_segment_revenue |
# |:------------------------|:------------------|----------:|---------------:|:--------------------------|--------------------------:|
# | FLIGHT_TYPE             | Multi-City        |    0.0384 |         5.9663 | Round-Trip                |                34870.9735 |
# | MARKET                  | NEW MERIDIAN      |    0.0287 |         4.4712 | UPPER APEX                |                25484.7571 |
# | route_direction         | AREA_B_TO_AREA_D  |    0.0254 |         3.9509 | AREA_C_TO_AREA_B          |                17874.4525 |
# | first_rbd               | D                 |    0.0220 |         3.4253 | L                         |                 8709.8411 |
# | is_hub_caj_route        | 0                 |    0.0169 |         2.6278 | 1                         |                27250.6633 |
# | stay_bucket             | 6_8               |    0.0156 |         2.4313 | 6_8                       |                15064.2383 |
# | pax_bucket              | 4_plus            |    0.0140 |         2.1730 | 1                         |                18086.0657 |
# | display_position_bucket | 6                 |    0.0132 |         2.0532 | 4                         |                11092.8599 |
# | destination_area        | AREA_D            |    0.0121 |         1.8764 | AREA_B                    |                21303.5799 |
# | first_booking_class     | C                 |    0.0119 |         1.8524 | Y                         |                41595.9696 |
# | has_child_or_infant     | 1                 |    0.0097 |         1.5056 | 0                         |                39185.8279 |
# | fare_bucket             | very_high         |    0.0090 |         1.4023 | very_high                 |                15948.7844 |
# | dtd_bucket              | 61_120            |    0.0084 |         1.3104 | 31_60                     |                10004.0746 |
# | origin_area             | AREA_D            |    0.0079 |         1.2344 | AREA_C                    |                35054.7296 |
# | emd_price_bucket        | very_high         |    0.0078 |         1.2105 | very_high                 |                33178.5799 |
# | LAST_TOUCH_CHANNEL      | Paid MetaSearches |    0.0077 |         1.2017 | Paid Search               |                15599.7876 |
# | FIRST_TOUCH_CHANNEL     | Referrals         |    0.0076 |         1.1849 | Direct                    |                20667.0409 |
# | BROWSER_TYPE            | google            |    0.0072 |         1.1162 | google                    |                22263.5013 |
# | LOGIN_STATUS            | Logged-Out        |    0.0067 |         1.0371 | Logged-Out                |                31716.0750 |
# | has_loyalty             | 0                 |    0.0064 |         1.0020 | 0                         |                39145.2636 |

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
base = Path("outputs/problem1/product_driver_analysis")
if not base.exists():
    base = Path("../product_driver_analysis")
driver_df = pd.read_csv(base / "special_equipment_driver_segments.csv")
driver_score = pd.read_csv(base / "special_equipment_driver_score.csv")

driver_df.head()

# %%
plot_df = driver_score.sort_values("best_cr_lift", ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(data=plot_df, y="driver", x="best_cr_lift", color="#2F6F9F")
plt.axvline(1, color="black", linewidth=1)
plt.title("Top drivers by best-segment CR lift")
plt.xlabel("Lift vs product baseline")
plt.ylabel("")
plt.tight_layout()

# %%
plot_df = driver_df.sort_values("revenue", ascending=False).head(15)
plt.figure(figsize=(10, 6))
sns.barplot(data=plot_df, y="segment_value", x="revenue", hue="driver", dodge=False)
plt.title("Highest-revenue segments")
plt.xlabel("Revenue")
plt.ylabel("")
plt.legend(loc="lower right")
plt.tight_layout()

# %%
plot_df = driver_df[driver_df["driver"].isin(["fare_bucket", "dtd_bucket", "stay_bucket", "FLIGHT_TYPE", "display_position_bucket"])].copy()
plot_df = plot_df.sort_values(["driver", "segment_value"])
g = sns.catplot(
    data=plot_df,
    kind="bar",
    x="segment_value",
    y="conversion_rate",
    col="driver",
    col_wrap=2,
    sharex=False,
    sharey=False,
    color="#2F6F9F",
    height=3.2,
    aspect=1.5,
)
g.set_xticklabels(rotation=35, ha="right")
g.set_axis_labels("", "Conversion rate")
g.fig.suptitle("Conversion rate by selected business buckets", y=1.03)
plt.tight_layout()

# %%
# Use this table to pick slide examples: high lift, enough volume, and meaningful revenue.
driver_df.query("offers >= 1000").sort_values(
    ["cr_lift_vs_product", "revenue"],
    ascending=False,
).head(25)
